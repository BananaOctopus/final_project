# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import numpy as np 
import seaborn as sn

# %%
#import flights_csv
flights_df = pd.read_csv('flights_update.csv')
flights_df.head(20)
# Out:
#     MONTH  DAY_OF_MONTH  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0       1             1            4      AS             98      N407AS
# 1       1             1            4      AA           2336      N3KUAA
# 2       1             1            4      US            840      N171US
# 3       1             1            4      AA            258      N3HYAA
# 4       1             1            4      AS            135      N527AS
# 5       1             1            4      DL            806      N3730B
# 6       1             1            4      NK            612      N635NK
# 7       1             1            4      US           2013      N584UW
# 8       1             1            4      AA           1112      N3LAAA
# 9       1             1            4      DL           1173      N826DN
# 10      1             1            4      DL           2336      N958DN
# 11      1             1            4      AA           1674      N853AA
# ...

# %%
#see types
flights_df.dtypes
# Out:
# MONTH                    int64
# DAY_OF_MONTH             int64
# DAY_OF_WEEK              int64
# AIRLINE                 object
# FLIGHT_NUMBER            int64
# TAIL_NUMBER             object
# ORIGIN_AIRPORT          object
# DESTINATION_AIRPORT     object
# DISTANCE                 int64
# MINUTES_DELAYED        float64
# dtype: object

# %%
#convert float64 to int64
flights_df['MINUTES_DELAYED'] = flights_df['MINUTES_DELAYED'].values.astype(np.int64)
print (flights_df['MINUTES_DELAYED'])
# Out:
# 0                          -22
# 1                           -9
# 2                            5
# 3                           -9
# 4                          -21
#                   ...
# 1048570                    -16
# 1048571                     -2
# 1048572                      3
# 1048573                    -13
# 1048574   -9223372036854775808
# Name: MINUTES_DELAYED, Length: 1048575, dtype: int64

# %%
#see types
flights_df.dtypes
# Out:
# MONTH                   int64
# DAY_OF_MONTH            int64
# DAY_OF_WEEK             int64
# AIRLINE                object
# FLIGHT_NUMBER           int64
# TAIL_NUMBER            object
# ORIGIN_AIRPORT         object
# DESTINATION_AIRPORT    object
# DISTANCE                int64
# MINUTES_DELAYED         int64
# dtype: object

# %%
#loc onto info I want
#flights_df1 = flights_df.loc[flights_df['MINUTES_DELAYED'] <= -1]
#flights_df1.head()

# %%
#loc onto info I want
#flights_df2 = flights_df.loc[flights_df['MINUTES_DELAYED'] >= 0]
#flights_df2.head()

# %%
#using data from only late flights
y = flights_df["MINUTES_DELAYED"]
X = flights_df.drop(columns="MINUTES_DELAYED")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(solver='lbfgs', random_state=1)
classifier
# Out:
# LogisticRegression(random_state=1)

# %%
LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
   intercept_scaling=1, max_iter=100, multi_class='warn', penalty='12',
   random_state=1, solver='lbfgs', tol=0.0001, warm_start=False)
# Out:
# LogisticRegression(multi_class='warn', penalty='12', random_state=1)

# %%
classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-f44724590846> in <module>
# ----> 1 classifier.fit(X_train, y_train)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1344         X, y = self._validate_data(X, y, accept_sparse='csr', dtype=_dtype,
#    1345                                    order="C",
# -> 1346                                    accept_large_sparse=solver != 'liblinear')
#    1347         check_classification_targets(y)
#    1348         self.classes_ = np.unique(y)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
# ...
